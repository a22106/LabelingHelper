# %%
import os
import json
import glob
import pandas as pd
import numpy as np

# %%
PASS = 0
REJECT = -1

CATEGORY_D = ["BICYCLE", "CAR", "BUS", "ETC", "MOTORCYCLE", "PEDESTRIAN", "TRUCK"]
CATEGORY_S = ["MEDIAN_STRIP", "OVERPASS", "RAMPSECT", "ROAD_SIGN", "SOUND_BARRIER", "STREET_TREES", "TUNNEL"]
CATEGORY_ATYP = ["MEDIAN_STRIP", "OVERPASS", "RAMPSECT", "SOUND_BARRIER", "TUNNEL"]

COLUMNS = ["clip 이름", "프레임 번호", "객체 id", "반려사유"]
SUM_COL = ["clip 이름", "검수결과", "반려사유"]

FILE_NUM_ERROR, FRAME_ERROR, CATEGORY_ERROR, ATYP_ERROR, LOC_ERROR, PCD_ERROR, POLYGON_ERROR, DIM_ERROR, GROUP_ERROR, SCENCE_ERROR = list(range(1,11))

dic = {
    PASS: "통과",
    REJECT: "반려",
    FILE_NUM_ERROR: "파일 개수 오류",
    FRAME_ERROR: "빈 프레임 오류",
    CATEGORY_ERROR: "객체종류 오류",
    ATYP_ERROR: "비정형/정형 오류",
    LOC_ERROR: "박스 위치 오류",
    PCD_ERROR: "PCD 부족 오류",
    POLYGON_ERROR: "폴리곤 오류",
    DIM_ERROR: "크기 오류",
    GROUP_ERROR: "그룹화 오류",
    SCENCE_ERROR: "시나리오 오류"
}

# %%
print("세령이 등장!!!!!!!!!!!!!!!!!!!!!!!!!!")
print("검수도구__ver. 0.2")
print("단일 json 단위만 구현 중(기준 50% 완료) / 모듈화 예정 / multi json 검수 추가예정")
# Out:
# 세령이 등장!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
class ErrorLogger:
    
    def __init__(self, clip_name):
        
        self.clip_name = clip_name
        self.is_reject = PASS
        self.err_type = []
        self.err_logging = pd.DataFrame(columns=COLUMNS)
    
    def set_clip_name(self, name):
        self.clip_name = name
    def set_reject(self, reject):
        self.is_reject = reject
    def add_err_type(self, err):
        self.err_type.append(err)
    def add_err_log(self, frame, object_id, err_type):
        row = [[self.get_clip_name(), frame, object_id, dic.get(err_type)]]
        l = pd.DataFrame(row, columns=COLUMNS)
        self.err_logging = pd.concat([self.get_err_log(), l], ignore_index=True)
        self.set_reject(REJECT)
        self.add_err_type(err_type)
        del l
    def add_pass_log(self):
        row = [[self.get_clip_name(), -1, -1, dic.get(PASS)]]
        l = pd.DataFrame(row, columns=COLUMNS)
        self.err_logging = pd.concat([self.get_err_log(), l], ignore_index=True)
        self.set_reject(PASS)
        self.add_err_type(PASS)
        del l
    
        
    def get_clip_name(self):
        return self.clip_name
    def get_reject(self):
        return self.is_reject
    def get_err_type(self):
        return set(self.err_type)
    def get_err_log(self):
        return self.err_logging
    def get_summary(self):
        root_clip = self.get_clip_name()
        res = dic.get(self.get_reject())
        
        err_type_list = list(self.get_err_type())
        err_type_list.sort()
        
        for i in range(len(err_type_list)):
            tmp = dic.get(err_type_list[i])
            err_type_list[i] = tmp
        err_type = ",".join(err_type_list)
        row = [[root_clip, res, err_type]]
        ret = pd.DataFrame(row, columns=SUM_COL)
        return ret

# %%
"""
추가예정 조건식 - 단일 JSON

PCD_ERROR: "",
POLYGON_ERROR: "",
DIM_ERROR: "",
GROUP_ERROR: "",
SCENCE_ERROR: ""

에러로그 한글화

"""

# %%
def rej_single_res(base_path, clip):
    res = glob.glob(f'{base_path}/{clip}/*')
    
    err_logger = ErrorLogger(clip)
    
    if len(res)<100: 
        print(f"{clip} reject labeling: not enough json number")
        err_logger.add_err_log(-1, -1, FILE_NUM_ERROR)
        return err_logger
    
    for r in res:
        with open(r, "r") as f:
            data = json.load(f)
            fnum = data["frame_no"]
            annot = data["annotation"]
            
            if annot == []:
                print(f"{clip}: frame {fnum}: is empty")
                err_logger.add_err_log(fnum, -1, FRAME_ERROR)
                
            for obj in annot:
                id = obj["id"]
                cat = obj["category"]
                type = obj["obj_type"]
                is_atyp = obj["atypical_yn"]
                box_list = obj["3d_box"]
                cam_vis = obj["camera_visibility"]
                polygon = obj["2d_polygon"]
                if type==0:
                    if cat not in CATEGORY_D: 
                        print(f"{clip}: frame {fnum}: object {id}: wrong category")
                        err_logger.add_err_log(fnum, id, CATEGORY_ERROR)
                else:
                    if cat not in CATEGORY_S:
                        print(f"{clip}: frame {fnum}: object {id}: wrong category")
                        err_logger.add_err_log(fnum, id, CATEGORY_ERROR)
                        
                if (cat in CATEGORY_ATYP): 
                    if is_atyp=="n":
                        print(f"{clip}: frame {fnum}: object {id}: wrong atypical_yn")
                        err_logger.add_err_log(fnum, id, ATYP_ERROR)
                else: 
                    if is_atyp=="y":
                        print(f"{clip}: frame {fnum}: object {id}: wrong atypical_yn")
                        err_logger.add_err_log(fnum, id, ATYP_ERROR)
                for box in box_list:
                    loc = box["location"]
                    if loc[0] < 0:
                        print(f"{clip}: frame {fnum}: object {id}: wrong location")
                        err_logger.add_err_log(fnum, id, LOC_ERROR)    
                    pcd_cnt = box["lidar_point_count"] + box["radar_point_count"]    
                    # if pcd_cnt < 3:
                    #     print(f"{clip}: frame {fnum} object {id} lack of point cloud")
    if err_logger.get_reject() == PASS:
        err_logger.add_pass_log()
    
    return err_logger
    
    
def iterate_clip(base_path):
    clip_folders = [i for i in os.listdir(base_path) 
                    if 'Clip_' in i]
    
    sum_log_df = pd.DataFrame(columns=SUM_COL)
    full_log_df = pd.DataFrame(columns=COLUMNS)
    
    rejected_clip = []
    for clip in clip_folders:
        el = rej_single_res(base_path, clip)
        
        sum_log = el.get_summary()
        sum_log_df = pd.concat([sum_log_df, sum_log], ignore_index=True)
        
        full_log = el.get_err_log()
        full_log_df = pd.concat([full_log_df, full_log], ignore_index=True)
        if el.get_reject() == REJECT:
            rejected_clip.append(clip)
            
    return sum_log_df, full_log_df


def get_scene(clip):
    ## 클립명에서 목표 객체 (동적or주행환경) 추출
    
    pass

# %%
# base = r"C:\workspace\rejecter\가공완료 클립\extract_2022-08-02-18-18-53"
# clip = "Clip_00033"
# el = reject_res(base, clip)
# res = el.get_err_log()

base = r"C:\workspace\rejecter\가공완료 클립\extract_2022-08-02-18-18-53"
sum, full = iterate_clip(base)
sum.to_csv("./sum.csv")
full.to_csv("./full.csv")
# Out:
# Clip_00001: frame 2: object 6: wrong atypical_yn
# Clip_00001: frame 3: object 6: wrong atypical_yn
# Clip_00001: frame 4: object 6: wrong atypical_yn
# Clip_00001: frame 5: object 6: wrong atypical_yn
# Clip_00001: frame 6: object 6: wrong atypical_yn
# Clip_00001: frame 7: object 6: wrong atypical_yn
# Clip_00001: frame 8: object 6: wrong atypical_yn
# Clip_00001: frame 9: object 6: wrong atypical_yn
# Clip_00001: frame 10: object 6: wrong atypical_yn
# Clip_00001: frame 11: object 6: wrong atypical_yn
# Clip_00001: frame 12: object 6: wrong atypical_yn
# Clip_00001: frame 13: object 6: wrong atypical_yn
# Clip_00001: frame 14: object 6: wrong atypical_yn
# Clip_00001: frame 15: object 6: wrong atypical_yn
# Clip_00001: frame 16: object 6: wrong atypical_yn
# Clip_00001: frame 17: object 6: wrong atypical_yn
# Clip_00001: frame 18: object 6: wrong atypical_yn
# Clip_00001: frame 19: object 6: wrong atypical_yn
# Clip_00001: frame 20: object 6: wrong atypical_yn
# Clip_00001: frame 21: object 6: wrong atypical_yn
# Clip_00001: frame 21: object 8: wrong atypical_yn
# Clip_00001: frame 22: object 6: wrong atypical_yn
# Clip_00001: frame 23: object 6: wrong atypical_yn
# Clip_00001: frame 24: object 6: wrong atypical_yn
# Clip_00001: frame 25: object 6: wrong atypical_yn
# Clip_00001: frame 26: object 6: wrong atypical_yn
# Clip_00001: frame 27: object 6: wrong atypical_yn
# Clip_00001: frame 28: object 6: wrong atypical_yn
# Clip_00001: frame 29: object 6: wrong atypical_yn
# Clip_00001: frame 30: object 6: wrong atypical_yn
# Clip_00001: frame 31: object 6: wrong atypical_yn
# Clip_00001: frame 32: object 6: wrong atypical_yn
# Clip_00001: frame 33: object 6: wrong atypical_yn
# Clip_00001: frame 34: object 6: wrong atypical_yn
# Clip_00001: frame 35: object 6: wrong atypical_yn
# Clip_00001: frame 36: object 6: wrong atypical_yn
# Clip_00001: frame 37: object 6: wrong atypical_yn
# Clip_00001: frame 38: object 6: wrong atypical_yn
# Clip_00001: frame 39: object 6: wrong atypical_yn
# Clip_00001: frame 40: object 6: wrong atypical_yn
# Clip_00001: frame 41: object 6: wrong atypical_yn
# Clip_00001: frame 42: object 6: wrong atypical_yn
# Clip_00001: frame 43: object 6: wrong atypical_yn
# Clip_00001: frame 44: object 6: wrong atypical_yn
# Clip_00001: frame 45: object 6: wrong atypical_yn
# Clip_00001: frame 46: object 3: wrong atypical_yn
# Clip_00001: frame 46: object 6: wrong atypical_yn
# Clip_00001: frame 47: object 6: wrong atypical_yn
# Clip_00001: frame 48: object 6: wrong atypical_yn
# Clip_00001: frame 49: object 6: wrong atypical_yn
# Clip_00001: frame 50: object 6: wrong atypical_yn
# Clip_00001: frame 51: object 6: wrong atypical_yn
# Clip_00001: frame 52: object 7: wrong atypical_yn
# Clip_00001: frame 53: object 6: wrong atypical_yn
# Clip_00001: frame 54: object 6: wrong atypical_yn
# Clip_00001: frame 55: object 6: wrong atypical_yn
# Clip_00001: frame 56: object 6: wrong atypical_yn
# Clip_00001: frame 57: object 6: wrong atypical_yn
# Clip_00001: frame 58: object 6: wrong atypical_yn
# Clip_00001: frame 59: object 6: wrong atypical_yn
# Clip_00001: frame 60: object 6: wrong atypical_yn
# Clip_00001: frame 61: object 6: wrong atypical_yn
# Clip_00001: frame 62: object 6: wrong atypical_yn
# Clip_00001: frame 63: object 6: wrong atypical_yn
# Clip_00001: frame 64: object 6: wrong atypical_yn
# Clip_00001: frame 65: object 6: wrong atypical_yn
# Clip_00001: frame 66: object 6: wrong atypical_yn
# Clip_00001: frame 67: object 6: wrong atypical_yn
# Clip_00001: frame 68: object 6: wrong atypical_yn
# Clip_00001: frame 69: object 6: wrong atypical_yn
# Clip_00001: frame 70: object 6: wrong atypical_yn
# Clip_00001: frame 71: object 6: wrong atypical_yn
# Clip_00001: frame 72: object 6: wrong atypical_yn
# Clip_00001: frame 73: object 6: wrong atypical_yn
# Clip_00001: frame 74: object 6: wrong atypical_yn
# Clip_00001: frame 75: object 6: wrong atypical_yn
# Clip_00001: frame 76: object 6: wrong atypical_yn
# Clip_00001: frame 77: object 7: wrong atypical_yn
# Clip_00001: frame 78: object 7: wrong atypical_yn
# Clip_00001: frame 79: object 6: wrong atypical_yn
# Clip_00001: frame 80: object 6: wrong atypical_yn
# Clip_00001: frame 81: object 6: wrong atypical_yn
# Clip_00001: frame 82: object 6: wrong atypical_yn
# Clip_00001: frame 83: object 6: wrong atypical_yn
# Clip_00001: frame 84: object 6: wrong atypical_yn
# Clip_00001: frame 85: object 6: wrong atypical_yn
# Clip_00001: frame 86: object 6: wrong atypical_yn
# Clip_00001: frame 87: object 6: wrong atypical_yn
# Clip_00001: frame 88: object 6: wrong atypical_yn
# Clip_00001: frame 89: object 6: wrong atypical_yn
# Clip_00001: frame 90: object 6: wrong atypical_yn
# Clip_00001: frame 91: object 6: wrong atypical_yn
# Clip_00001: frame 92: object 6: wrong atypical_yn
# Clip_00001: frame 93: object 6: wrong atypical_yn
# Clip_00001: frame 94: object 6: wrong atypical_yn
# Clip_00001: frame 95: object 6: wrong atypical_yn
# Clip_00001: frame 96: object 6: wrong atypical_yn
# Clip_00001: frame 97: object 6: wrong atypical_yn
# Clip_00001: frame 98: object 6: wrong atypical_yn
# Clip_00001: frame 99: object 6: wrong atypical_yn
# Clip_00001: frame 100: object 6: wrong atypical_yn
# Clip_00003 reject labeling: not enough json number
# Clip_00011: frame 39: object 9: wrong atypical_yn
# Clip_00011: frame 39: object 10: wrong atypical_yn
# Clip_00011: frame 40: object 9: wrong atypical_yn
# Clip_00011: frame 40: object 10: wrong atypical_yn
# Clip_00011: frame 41: object 9: wrong atypical_yn
# Clip_00011: frame 41: object 10: wrong atypical_yn
# Clip_00011: frame 42: object 9: wrong atypical_yn
# Clip_00011: frame 42: object 10: wrong atypical_yn
# Clip_00011: frame 43: object 9: wrong atypical_yn
# Clip_00011: frame 43: object 10: wrong atypical_yn
# Clip_00011: frame 44: object 9: wrong atypical_yn
# Clip_00011: frame 44: object 10: wrong atypical_yn
# Clip_00011: frame 45: object 9: wrong atypical_yn
# Clip_00011: frame 45: object 10: wrong atypical_yn
# Clip_00011: frame 46: object 9: wrong atypical_yn
# Clip_00011: frame 46: object 10: wrong atypical_yn
# Clip_00011: frame 47: object 10: wrong atypical_yn
# Clip_00011: frame 48: object 10: wrong atypical_yn
# Clip_00011: frame 80: object 16: wrong atypical_yn
# Clip_00011: frame 81: object 16: wrong atypical_yn
# Clip_00011: frame 82: object 16: wrong atypical_yn
# Clip_00011: frame 83: object 16: wrong atypical_yn
# Clip_00011: frame 84: object 16: wrong atypical_yn
# Clip_00017: frame 13: object 6: wrong atypical_yn
# Clip_00017: frame 20: object 2: wrong atypical_yn
# Clip_00017: frame 96: object 5: wrong location
# 14101
# Clip_00017: frame 97: object 5: wrong location
# 9158
# Clip_00021: frame 0: object 1: wrong category
# Clip_00021: frame 0: object 1: wrong atypical_yn
# Clip_00022: frame 4: object 1: wrong atypical_yn
# Clip_00022: frame 39: object 1: wrong category
# Clip_00022: frame 39: object 1: wrong atypical_yn
# Clip_00022: frame 40: object 1: wrong category
# Clip_00022: frame 40: object 1: wrong atypical_yn
# Clip_00022: frame 95: object 3: wrong atypical_yn
# Clip_00022: frame 96: object 3: wrong atypical_yn
# Clip_00022: frame 98: object 3: wrong atypical_yn
# Clip_00022: frame 99: object 3: wrong atypical_yn
# Clip_00022: frame 100: object 3: wrong atypical_yn
# Clip_00028: frame 1: object 1: wrong atypical_yn
# Clip_00028: frame 1: object 2: wrong atypical_yn
# Clip_00028: frame 1: object 3: wrong atypical_yn
# Clip_00028: frame 1: object 4: wrong atypical_yn
# Clip_00028: frame 2: object 1: wrong atypical_yn
# Clip_00028: frame 2: object 2: wrong atypical_yn
# Clip_00028: frame 2: object 4: wrong atypical_yn
# Clip_00028: frame 2: object 5: wrong atypical_yn
# Clip_00028: frame 3: object 1: wrong atypical_yn
# Clip_00028: frame 3: object 2: wrong atypical_yn
# Clip_00028: frame 3: object 4: wrong atypical_yn
# Clip_00028: frame 3: object 7: wrong atypical_yn
# Clip_00028: frame 4: object 2: wrong atypical_yn
# Clip_00028: frame 4: object 3: wrong atypical_yn
# Clip_00028: frame 4: object 4: wrong atypical_yn
# Clip_00028: frame 4: object 9: wrong atypical_yn
# Clip_00028: frame 5: object 2: wrong atypical_yn
# Clip_00028: frame 5: object 4: wrong atypical_yn
# Clip_00028: frame 5: object 5: wrong atypical_yn
# Clip_00028: frame 5: object 11: wrong atypical_yn
# Clip_00028: frame 6: object 2: wrong atypical_yn
# Clip_00028: frame 6: object 4: wrong atypical_yn
# Clip_00028: frame 6: object 7: wrong atypical_yn
# Clip_00028: frame 6: object 13: wrong atypical_yn
# Clip_00028: frame 7: object 2: wrong atypical_yn
# Clip_00028: frame 7: object 4: wrong atypical_yn
# Clip_00028: frame 7: object 9: wrong atypical_yn
# Clip_00028: frame 7: object 15: wrong atypical_yn
# Clip_00028: frame 8: object 2: wrong atypical_yn
# Clip_00028: frame 8: object 5: wrong atypical_yn
# Clip_00028: frame 8: object 10: wrong atypical_yn
# Clip_00028: frame 8: object 16: wrong atypical_yn
# Clip_00028: frame 9: object 2: wrong atypical_yn
# Clip_00028: frame 9: object 5: wrong atypical_yn
# Clip_00028: frame 9: object 12: wrong atypical_yn
# Clip_00028: frame 9: object 17: wrong atypical_yn
# Clip_00028: frame 10: object 2: wrong atypical_yn
# Clip_00028: frame 10: object 5: wrong atypical_yn
# Clip_00028: frame 10: object 14: wrong atypical_yn
# Clip_00028: frame 10: object 18: wrong atypical_yn
# Clip_00028: frame 11: object 2: wrong atypical_yn
# Clip_00028: frame 11: object 5: wrong atypical_yn
# Clip_00028: frame 11: object 16: wrong atypical_yn
# Clip_00028: frame 11: object 19: wrong atypical_yn
# Clip_00028: frame 12: object 2: wrong atypical_yn
# Clip_00028: frame 12: object 5: wrong atypical_yn
# Clip_00028: frame 12: object 18: wrong atypical_yn
# Clip_00028: frame 12: object 22: wrong atypical_yn
# Clip_00028: frame 13: object 2: wrong atypical_yn
# Clip_00028: frame 13: object 5: wrong atypical_yn
# Clip_00028: frame 13: object 20: wrong atypical_yn
# Clip_00028: frame 13: object 23: wrong atypical_yn
# Clip_00028: frame 14: object 2: wrong atypical_yn
# Clip_00028: frame 14: object 5: wrong atypical_yn
# Clip_00028: frame 14: object 22: wrong atypical_yn
# Clip_00028: frame 14: object 24: wrong atypical_yn
# Clip_00028: frame 15: object 2: wrong atypical_yn
# Clip_00028: frame 15: object 5: wrong atypical_yn
# Clip_00028: frame 15: object 24: wrong atypical_yn
# Clip_00028: frame 15: object 25: wrong atypical_yn
# Clip_00028: frame 16: object 2: wrong atypical_yn
# Clip_00028: frame 16: object 5: wrong atypical_yn
# Clip_00028: frame 16: object 26: wrong atypical_yn
# Clip_00028: frame 16: object 27: wrong atypical_yn
# Clip_00028: frame 17: object 2: wrong atypical_yn
# Clip_00028: frame 17: object 5: wrong atypical_yn
# Clip_00028: frame 17: object 27: wrong atypical_yn
# Clip_00028: frame 17: object 30: wrong atypical_yn
# Clip_00028: frame 18: object 2: wrong atypical_yn
# Clip_00028: frame 18: object 5: wrong atypical_yn
# Clip_00028: frame 18: object 28: wrong atypical_yn
# Clip_00028: frame 18: object 33: wrong atypical_yn
# Clip_00028: frame 19: object 2: wrong atypical_yn
# Clip_00028: frame 19: object 5: wrong atypical_yn
# Clip_00028: frame 19: object 29: wrong atypical_yn
# Clip_00028: frame 19: object 36: wrong atypical_yn
# Clip_00028: frame 20: object 2: wrong atypical_yn
# Clip_00028: frame 20: object 5: wrong atypical_yn
# Clip_00028: frame 20: object 31: wrong atypical_yn
# Clip_00028: frame 20: object 39: wrong atypical_yn
# Clip_00028: frame 21: object 2: wrong atypical_yn
# Clip_00028: frame 21: object 5: wrong atypical_yn
# Clip_00028: frame 21: object 32: wrong atypical_yn
# Clip_00028: frame 21: object 42: wrong atypical_yn
# Clip_00028: frame 22: object 2: wrong atypical_yn
# Clip_00028: frame 22: object 5: wrong atypical_yn
# Clip_00028: frame 22: object 33: wrong atypical_yn
# Clip_00028: frame 22: object 45: wrong atypical_yn
# Clip_00028: frame 23: object 2: wrong atypical_yn
# Clip_00028: frame 23: object 5: wrong atypical_yn
# Clip_00028: frame 23: object 34: wrong atypical_yn
# Clip_00028: frame 23: object 48: wrong atypical_yn
# Clip_00028: frame 24: object 2: wrong atypical_yn
# Clip_00028: frame 24: object 5: wrong atypical_yn
# Clip_00028: frame 24: object 35: wrong atypical_yn
# Clip_00028: frame 24: object 51: wrong atypical_yn
# Clip_00028: frame 25: object 2: wrong atypical_yn
# Clip_00028: frame 25: object 5: wrong atypical_yn
# Clip_00028: frame 25: object 36: wrong atypical_yn
# Clip_00028: frame 25: object 54: wrong atypical_yn
# Clip_00028: frame 26: object 2: wrong atypical_yn
# Clip_00028: frame 26: object 5: wrong atypical_yn
# Clip_00028: frame 26: object 37: wrong atypical_yn
# Clip_00028: frame 26: object 57: wrong atypical_yn
# Clip_00028: frame 27: object 2: wrong atypical_yn
# Clip_00028: frame 27: object 5: wrong atypical_yn
# Clip_00028: frame 27: object 38: wrong atypical_yn
# Clip_00028: frame 27: object 60: wrong atypical_yn
# Clip_00028: frame 28: object 2: wrong atypical_yn
# Clip_00028: frame 28: object 5: wrong atypical_yn
# Clip_00028: frame 28: object 39: wrong atypical_yn
# Clip_00028: frame 28: object 63: wrong atypical_yn
# Clip_00028: frame 29: object 2: wrong atypical_yn
# Clip_00028: frame 29: object 5: wrong atypical_yn
# Clip_00028: frame 29: object 40: wrong atypical_yn
# Clip_00028: frame 29: object 66: wrong atypical_yn
# Clip_00028: frame 30: object 2: wrong atypical_yn
# Clip_00028: frame 30: object 5: wrong atypical_yn
# Clip_00028: frame 30: object 41: wrong atypical_yn
# Clip_00028: frame 30: object 69: wrong atypical_yn
# Clip_00028: frame 31: object 2: wrong atypical_yn
# Clip_00028: frame 31: object 5: wrong atypical_yn
# Clip_00028: frame 31: object 42: wrong atypical_yn
# Clip_00028: frame 31: object 72: wrong atypical_yn
# Clip_00028: frame 32: object 2: wrong atypical_yn
# Clip_00028: frame 32: object 5: wrong atypical_yn
# Clip_00028: frame 32: object 43: wrong atypical_yn
# Clip_00028: frame 32: object 75: wrong atypical_yn
# Clip_00028: frame 33: object 2: wrong atypical_yn
# Clip_00028: frame 33: object 5: wrong atypical_yn
# Clip_00028: frame 33: object 43: wrong atypical_yn
# Clip_00028: frame 33: object 75: wrong atypical_yn
# Clip_00028: frame 34: object 2: wrong atypical_yn
# Clip_00028: frame 34: object 5: wrong atypical_yn
# Clip_00028: frame 34: object 43: wrong atypical_yn
# Clip_00028: frame 34: object 75: wrong atypical_yn
# Clip_00028: frame 35: object 2: wrong atypical_yn
# Clip_00028: frame 35: object 5: wrong atypical_yn
# Clip_00028: frame 35: object 43: wrong atypical_yn
# Clip_00028: frame 35: object 75: wrong atypical_yn
# Clip_00028: frame 36: object 2: wrong atypical_yn
# Clip_00028: frame 36: object 5: wrong atypical_yn
# Clip_00028: frame 36: object 43: wrong atypical_yn
# Clip_00028: frame 36: object 75: wrong atypical_yn
# Clip_00028: frame 37: object 2: wrong atypical_yn
# Clip_00028: frame 37: object 5: wrong atypical_yn
# Clip_00028: frame 37: object 43: wrong atypical_yn
# Clip_00028: frame 37: object 75: wrong atypical_yn
# Clip_00028: frame 38: object 2: wrong atypical_yn
# Clip_00028: frame 38: object 5: wrong atypical_yn
# Clip_00028: frame 38: object 43: wrong atypical_yn
# Clip_00028: frame 38: object 75: wrong atypical_yn
# Clip_00028: frame 39: object 2: wrong atypical_yn
# Clip_00028: frame 39: object 5: wrong atypical_yn
# Clip_00028: frame 39: object 43: wrong atypical_yn
# Clip_00028: frame 39: object 75: wrong atypical_yn
# Clip_00028: frame 40: object 2: wrong atypical_yn
# Clip_00028: frame 40: object 5: wrong atypical_yn
# Clip_00028: frame 40: object 43: wrong atypical_yn
# Clip_00028: frame 40: object 75: wrong atypical_yn
# Clip_00028: frame 41: object 2: wrong atypical_yn
# Clip_00028: frame 41: object 5: wrong atypical_yn
# Clip_00028: frame 41: object 43: wrong atypical_yn
# Clip_00028: frame 41: object 75: wrong atypical_yn
# Clip_00028: frame 42: object 2: wrong atypical_yn
# Clip_00028: frame 42: object 5: wrong atypical_yn
# Clip_00028: frame 42: object 43: wrong atypical_yn
# Clip_00028: frame 42: object 75: wrong atypical_yn
# Clip_00028: frame 43: object 2: wrong atypical_yn
# Clip_00028: frame 43: object 5: wrong atypical_yn
# Clip_00028: frame 43: object 43: wrong atypical_yn
# Clip_00028: frame 43: object 75: wrong atypical_yn
# Clip_00028: frame 44: object 2: wrong atypical_yn
# Clip_00028: frame 44: object 5: wrong atypical_yn
# Clip_00028: frame 44: object 43: wrong atypical_yn
# Clip_00028: frame 44: object 75: wrong atypical_yn
# Clip_00028: frame 45: object 2: wrong atypical_yn
# Clip_00028: frame 45: object 5: wrong atypical_yn
# Clip_00028: frame 45: object 43: wrong atypical_yn
# Clip_00028: frame 45: object 75: wrong atypical_yn
# Clip_00028: frame 46: object 2: wrong atypical_yn
# Clip_00028: frame 46: object 5: wrong atypical_yn
# Clip_00028: frame 46: object 43: wrong atypical_yn
# Clip_00028: frame 46: object 75: wrong atypical_yn
# Clip_00028: frame 47: object 2: wrong atypical_yn
# Clip_00028: frame 47: object 5: wrong atypical_yn
# Clip_00028: frame 47: object 43: wrong atypical_yn
# Clip_00028: frame 47: object 75: wrong atypical_yn
# Clip_00028: frame 48: object 2: wrong atypical_yn
# Clip_00028: frame 48: object 5: wrong atypical_yn
# Clip_00028: frame 48: object 43: wrong atypical_yn
# Clip_00028: frame 48: object 75: wrong atypical_yn
# Clip_00028: frame 49: object 2: wrong atypical_yn
# Clip_00028: frame 49: object 5: wrong atypical_yn
# Clip_00028: frame 49: object 43: wrong atypical_yn
# Clip_00028: frame 49: object 75: wrong atypical_yn
# Clip_00028: frame 50: object 2: wrong atypical_yn
# Clip_00028: frame 50: object 5: wrong atypical_yn
# Clip_00028: frame 50: object 43: wrong atypical_yn
# Clip_00028: frame 50: object 75: wrong atypical_yn
# Clip_00028: frame 51: object 2: wrong atypical_yn
# Clip_00028: frame 51: object 5: wrong atypical_yn
# Clip_00028: frame 51: object 43: wrong atypical_yn
# Clip_00028: frame 51: object 75: wrong atypical_yn
# Clip_00028: frame 52: object 2: wrong atypical_yn
# Clip_00028: frame 52: object 5: wrong atypical_yn
# Clip_00028: frame 52: object 43: wrong atypical_yn
# Clip_00028: frame 52: object 75: wrong atypical_yn
# Clip_00028: frame 53: object 2: wrong atypical_yn
# Clip_00028: frame 53: object 5: wrong atypical_yn
# Clip_00028: frame 53: object 43: wrong atypical_yn
# Clip_00028: frame 53: object 75: wrong atypical_yn
# Clip_00028: frame 54: object 2: wrong atypical_yn
# Clip_00028: frame 54: object 5: wrong atypical_yn
# Clip_00028: frame 54: object 43: wrong atypical_yn
# Clip_00028: frame 54: object 75: wrong atypical_yn
# Clip_00028: frame 55: object 2: wrong atypical_yn
# Clip_00028: frame 55: object 5: wrong atypical_yn
# Clip_00028: frame 55: object 43: wrong atypical_yn
# Clip_00028: frame 55: object 75: wrong atypical_yn
# Clip_00028: frame 56: object 2: wrong atypical_yn
# Clip_00028: frame 56: object 5: wrong atypical_yn
# Clip_00028: frame 56: object 43: wrong atypical_yn
# Clip_00028: frame 56: object 75: wrong atypical_yn
# Clip_00028: frame 57: object 2: wrong atypical_yn
# Clip_00028: frame 57: object 5: wrong atypical_yn
# Clip_00028: frame 57: object 43: wrong atypical_yn
# Clip_00028: frame 57: object 75: wrong atypical_yn
# Clip_00028: frame 58: object 2: wrong atypical_yn
# Clip_00028: frame 58: object 5: wrong atypical_yn
# Clip_00028: frame 58: object 43: wrong atypical_yn
# Clip_00028: frame 58: object 75: wrong atypical_yn
# Clip_00028: frame 59: object 2: wrong atypical_yn
# Clip_00028: frame 59: object 5: wrong atypical_yn
# Clip_00028: frame 59: object 43: wrong atypical_yn
# Clip_00028: frame 59: object 75: wrong atypical_yn
# Clip_00028: frame 60: object 2: wrong atypical_yn
# Clip_00028: frame 60: object 5: wrong atypical_yn
# Clip_00028: frame 60: object 43: wrong atypical_yn
# Clip_00028: frame 60: object 75: wrong atypical_yn
# Clip_00028: frame 61: object 2: wrong atypical_yn
# Clip_00028: frame 61: object 5: wrong atypical_yn
# Clip_00028: frame 61: object 43: wrong atypical_yn
# Clip_00028: frame 61: object 75: wrong atypical_yn
# Clip_00028: frame 62: object 2: wrong atypical_yn
# Clip_00028: frame 62: object 5: wrong atypical_yn
# Clip_00028: frame 62: object 43: wrong atypical_yn
# Clip_00028: frame 62: object 75: wrong atypical_yn
# Clip_00028: frame 63: object 2: wrong atypical_yn
# Clip_00028: frame 63: object 5: wrong atypical_yn
# Clip_00028: frame 63: object 43: wrong atypical_yn
# Clip_00028: frame 63: object 75: wrong atypical_yn
# Clip_00028: frame 64: object 2: wrong atypical_yn
# Clip_00028: frame 64: object 5: wrong atypical_yn
# Clip_00028: frame 64: object 43: wrong atypical_yn
# Clip_00028: frame 64: object 75: wrong atypical_yn
# Clip_00028: frame 65: object 2: wrong atypical_yn
# Clip_00028: frame 65: object 5: wrong atypical_yn
# Clip_00028: frame 65: object 43: wrong atypical_yn
# Clip_00028: frame 65: object 75: wrong atypical_yn
# Clip_00028: frame 66: object 2: wrong atypical_yn
# Clip_00028: frame 66: object 5: wrong atypical_yn
# Clip_00028: frame 66: object 43: wrong atypical_yn
# Clip_00028: frame 66: object 75: wrong atypical_yn
# Clip_00028: frame 67: object 2: wrong atypical_yn
# Clip_00028: frame 67: object 5: wrong atypical_yn
# Clip_00028: frame 67: object 43: wrong atypical_yn
# Clip_00028: frame 67: object 75: wrong atypical_yn
# Clip_00028: frame 68: object 2: wrong atypical_yn
# Clip_00028: frame 68: object 5: wrong atypical_yn
# Clip_00028: frame 68: object 43: wrong atypical_yn
# Clip_00028: frame 68: object 75: wrong atypical_yn
# Clip_00028: frame 69: object 2: wrong atypical_yn
# Clip_00028: frame 69: object 5: wrong atypical_yn
# Clip_00028: frame 69: object 43: wrong atypical_yn
# Clip_00028: frame 69: object 75: wrong atypical_yn
# Clip_00028: frame 70: object 2: wrong atypical_yn
# Clip_00028: frame 70: object 5: wrong atypical_yn
# Clip_00028: frame 70: object 43: wrong atypical_yn
# Clip_00028: frame 70: object 75: wrong atypical_yn
# Clip_00028: frame 71: object 2: wrong atypical_yn
# Clip_00028: frame 71: object 5: wrong atypical_yn
# Clip_00028: frame 71: object 43: wrong atypical_yn
# Clip_00028: frame 71: object 75: wrong atypical_yn
# Clip_00028: frame 72: object 2: wrong atypical_yn
# Clip_00028: frame 72: object 5: wrong atypical_yn
# Clip_00028: frame 72: object 43: wrong atypical_yn
# Clip_00028: frame 72: object 75: wrong atypical_yn
# Clip_00028: frame 73: object 2: wrong atypical_yn
# Clip_00028: frame 73: object 5: wrong atypical_yn
# Clip_00028: frame 73: object 43: wrong atypical_yn
# Clip_00028: frame 73: object 75: wrong atypical_yn
# Clip_00028: frame 74: object 2: wrong atypical_yn
# Clip_00028: frame 74: object 5: wrong atypical_yn
# Clip_00028: frame 74: object 43: wrong atypical_yn
# Clip_00028: frame 74: object 75: wrong atypical_yn
# Clip_00028: frame 75: object 2: wrong atypical_yn
# Clip_00028: frame 75: object 5: wrong atypical_yn
# Clip_00028: frame 75: object 43: wrong atypical_yn
# Clip_00028: frame 75: object 75: wrong atypical_yn
# Clip_00028: frame 76: object 2: wrong atypical_yn
# Clip_00028: frame 76: object 5: wrong atypical_yn
# Clip_00028: frame 76: object 43: wrong atypical_yn
# Clip_00028: frame 76: object 75: wrong atypical_yn
# Clip_00028: frame 77: object 2: wrong atypical_yn
# Clip_00028: frame 77: object 5: wrong atypical_yn
# Clip_00028: frame 77: object 43: wrong atypical_yn
# Clip_00028: frame 77: object 75: wrong atypical_yn
# Clip_00028: frame 78: object 2: wrong atypical_yn
# Clip_00028: frame 78: object 5: wrong atypical_yn
# Clip_00028: frame 78: object 43: wrong atypical_yn
# Clip_00028: frame 78: object 75: wrong atypical_yn
# Clip_00028: frame 79: object 2: wrong atypical_yn
# Clip_00028: frame 79: object 5: wrong atypical_yn
# Clip_00028: frame 79: object 43: wrong atypical_yn
# Clip_00028: frame 79: object 75: wrong atypical_yn
# Clip_00028: frame 80: object 2: wrong atypical_yn
# Clip_00028: frame 80: object 5: wrong atypical_yn
# Clip_00028: frame 80: object 43: wrong atypical_yn
# Clip_00028: frame 80: object 75: wrong atypical_yn
# Clip_00028: frame 81: object 2: wrong atypical_yn
# Clip_00028: frame 81: object 5: wrong atypical_yn
# Clip_00028: frame 81: object 43: wrong atypical_yn
# Clip_00028: frame 81: object 75: wrong atypical_yn
# Clip_00028: frame 82: object 2: wrong atypical_yn
# Clip_00028: frame 82: object 5: wrong atypical_yn
# Clip_00028: frame 82: object 43: wrong atypical_yn
# Clip_00028: frame 82: object 75: wrong atypical_yn
# Clip_00028: frame 83: object 2: wrong atypical_yn
# Clip_00028: frame 83: object 5: wrong atypical_yn
# Clip_00028: frame 83: object 43: wrong atypical_yn
# Clip_00028: frame 83: object 75: wrong atypical_yn
# Clip_00028: frame 84: object 2: wrong atypical_yn
# Clip_00028: frame 84: object 5: wrong atypical_yn
# Clip_00028: frame 84: object 43: wrong atypical_yn
# Clip_00028: frame 84: object 75: wrong atypical_yn
# Clip_00028: frame 85: object 2: wrong atypical_yn
# Clip_00028: frame 85: object 5: wrong atypical_yn
# Clip_00028: frame 85: object 43: wrong atypical_yn
# Clip_00028: frame 85: object 75: wrong atypical_yn
# Clip_00028: frame 86: object 2: wrong atypical_yn
# Clip_00028: frame 86: object 5: wrong atypical_yn
# Clip_00028: frame 86: object 43: wrong atypical_yn
# Clip_00028: frame 86: object 75: wrong atypical_yn
# Clip_00028: frame 87: object 2: wrong atypical_yn
# Clip_00028: frame 87: object 5: wrong atypical_yn
# Clip_00028: frame 87: object 43: wrong atypical_yn
# Clip_00028: frame 87: object 75: wrong atypical_yn
# Clip_00028: frame 88: object 2: wrong atypical_yn
# Clip_00028: frame 88: object 5: wrong atypical_yn
# Clip_00028: frame 88: object 43: wrong atypical_yn
# Clip_00028: frame 88: object 75: wrong atypical_yn
# Clip_00028: frame 89: object 2: wrong atypical_yn
# Clip_00028: frame 89: object 5: wrong atypical_yn
# Clip_00028: frame 89: object 43: wrong atypical_yn
# Clip_00028: frame 89: object 75: wrong atypical_yn
# Clip_00028: frame 90: object 2: wrong atypical_yn
# Clip_00028: frame 90: object 5: wrong atypical_yn
# Clip_00028: frame 90: object 43: wrong atypical_yn
# Clip_00028: frame 90: object 75: wrong atypical_yn
# Clip_00028: frame 91: object 2: wrong atypical_yn
# Clip_00028: frame 91: object 5: wrong atypical_yn
# Clip_00028: frame 91: object 43: wrong atypical_yn
# Clip_00028: frame 91: object 75: wrong atypical_yn
# Clip_00028: frame 92: object 2: wrong atypical_yn
# Clip_00028: frame 92: object 5: wrong atypical_yn
# Clip_00028: frame 92: object 43: wrong atypical_yn
# Clip_00028: frame 92: object 75: wrong atypical_yn
# Clip_00028: frame 93: object 2: wrong atypical_yn
# Clip_00028: frame 93: object 5: wrong atypical_yn
# Clip_00028: frame 93: object 43: wrong atypical_yn
# Clip_00028: frame 93: object 75: wrong atypical_yn
# Clip_00028: frame 94: object 2: wrong atypical_yn
# Clip_00028: frame 94: object 5: wrong atypical_yn
# Clip_00028: frame 94: object 43: wrong atypical_yn
# Clip_00028: frame 94: object 75: wrong atypical_yn
# Clip_00028: frame 95: object 2: wrong atypical_yn
# Clip_00028: frame 95: object 5: wrong atypical_yn
# Clip_00028: frame 95: object 43: wrong atypical_yn
# Clip_00028: frame 95: object 75: wrong atypical_yn
# Clip_00028: frame 96: object 2: wrong atypical_yn
# Clip_00028: frame 96: object 5: wrong atypical_yn
# Clip_00028: frame 96: object 75: wrong atypical_yn
# Clip_00028: frame 97: object 2: wrong atypical_yn
# Clip_00028: frame 97: object 5: wrong atypical_yn
# Clip_00028: frame 97: object 75: wrong atypical_yn
# Clip_00028: frame 98: object 2: wrong atypical_yn
# Clip_00028: frame 98: object 5: wrong atypical_yn
# Clip_00028: frame 98: object 75: wrong atypical_yn
# Clip_00028: frame 99: object 2: wrong atypical_yn
# Clip_00028: frame 99: object 5: wrong atypical_yn
# Clip_00028: frame 99: object 75: wrong atypical_yn
# Clip_00028: frame 100: object 2: wrong atypical_yn
# Clip_00028: frame 100: object 5: wrong atypical_yn
# Clip_00028: frame 100: object 75: wrong atypical_yn
# Clip_00033: frame 1: object 1: wrong category
# Clip_00033: frame 1: object 1: wrong atypical_yn
# Clip_00033: frame 2: object 1: wrong category
# Clip_00033: frame 2: object 1: wrong atypical_yn
# Clip_00033: frame 3: object 1: wrong category
# Clip_00033: frame 3: object 1: wrong atypical_yn
# Clip_00033: frame 4: object 1: wrong category
# Clip_00033: frame 4: object 1: wrong atypical_yn
# Clip_00033: frame 5: object 1: wrong category
# Clip_00033: frame 5: object 1: wrong atypical_yn
# Clip_00033: frame 5: object 4: wrong atypical_yn
# Clip_00033: frame 6: object 1: wrong category
# Clip_00033: frame 6: object 1: wrong atypical_yn
# Clip_00033: frame 6: object 4: wrong atypical_yn
# Clip_00033: frame 7: object 1: wrong category
# Clip_00033: frame 7: object 1: wrong atypical_yn
# Clip_00033: frame 7: object 4: wrong atypical_yn
# Clip_00033: frame 8: object 1: wrong category
# Clip_00033: frame 8: object 1: wrong atypical_yn
# Clip_00033: frame 8: object 4: wrong atypical_yn
# Clip_00033: frame 9: object 1: wrong category
# Clip_00033: frame 9: object 1: wrong atypical_yn
# Clip_00033: frame 9: object 4: wrong atypical_yn
# Clip_00033: frame 10: object 1: wrong category
# Clip_00033: frame 10: object 1: wrong atypical_yn
# Clip_00033: frame 10: object 4: wrong atypical_yn
# Clip_00033: frame 11: object 1: wrong category
# Clip_00033: frame 11: object 1: wrong atypical_yn
# Clip_00033: frame 11: object 4: wrong atypical_yn
# Clip_00033: frame 12: object 1: wrong category
# Clip_00033: frame 12: object 1: wrong atypical_yn
# Clip_00033: frame 12: object 4: wrong atypical_yn
# Clip_00033: frame 13: object 1: wrong category
# Clip_00033: frame 13: object 1: wrong atypical_yn
# Clip_00033: frame 13: object 4: wrong atypical_yn
# Clip_00033: frame 14: object 1: wrong category
# Clip_00033: frame 14: object 1: wrong atypical_yn
# Clip_00033: frame 14: object 4: wrong atypical_yn
# Clip_00033: frame 15: object 1: wrong category
# Clip_00033: frame 15: object 1: wrong atypical_yn
# Clip_00033: frame 15: object 4: wrong atypical_yn
# Clip_00033: frame 16: object 1: wrong category
# Clip_00033: frame 16: object 1: wrong atypical_yn
# Clip_00033: frame 16: object 4: wrong atypical_yn
# Clip_00033: frame 17: object 1: wrong category
# Clip_00033: frame 17: object 1: wrong atypical_yn
# Clip_00033: frame 17: object 4: wrong atypical_yn
# Clip_00033: frame 18: object 1: wrong category
# Clip_00033: frame 18: object 1: wrong atypical_yn
# Clip_00033: frame 18: object 4: wrong atypical_yn
# Clip_00033: frame 19: object 1: wrong category
# Clip_00033: frame 19: object 1: wrong atypical_yn
# Clip_00033: frame 19: object 4: wrong atypical_yn
# Clip_00033: frame 20: object 1: wrong category
# Clip_00033: frame 20: object 1: wrong atypical_yn
# Clip_00033: frame 20: object 4: wrong atypical_yn
# Clip_00033: frame 21: object 1: wrong category
# Clip_00033: frame 21: object 1: wrong atypical_yn
# Clip_00033: frame 21: object 4: wrong atypical_yn
# Clip_00033: frame 22: object 1: wrong category
# Clip_00033: frame 22: object 1: wrong atypical_yn
# Clip_00033: frame 22: object 4: wrong atypical_yn
# Clip_00033: frame 23: object 1: wrong category
# Clip_00033: frame 23: object 1: wrong atypical_yn
# Clip_00033: frame 23: object 4: wrong atypical_yn
# Clip_00033: frame 24: object 1: wrong category
# Clip_00033: frame 24: object 1: wrong atypical_yn
# Clip_00033: frame 24: object 4: wrong atypical_yn
# Clip_00033: frame 25: object 1: wrong category
# Clip_00033: frame 25: object 1: wrong atypical_yn
# Clip_00033: frame 25: object 4: wrong atypical_yn
# Clip_00033: frame 26: object 1: wrong category
# Clip_00033: frame 26: object 1: wrong atypical_yn
# Clip_00033: frame 26: object 4: wrong atypical_yn
# Clip_00033: frame 27: object 1: wrong category
# Clip_00033: frame 27: object 1: wrong atypical_yn
# Clip_00033: frame 27: object 4: wrong atypical_yn
# Clip_00033: frame 28: object 1: wrong category
# Clip_00033: frame 28: object 1: wrong atypical_yn
# Clip_00033: frame 28: object 4: wrong atypical_yn
# Clip_00033: frame 29: object 1: wrong category
# Clip_00033: frame 29: object 1: wrong atypical_yn
# Clip_00033: frame 29: object 4: wrong atypical_yn
# Clip_00033: frame 30: object 1: wrong category
# Clip_00033: frame 30: object 1: wrong atypical_yn
# Clip_00033: frame 30: object 4: wrong atypical_yn
# Clip_00033: frame 31: object 1: wrong category
# Clip_00033: frame 31: object 1: wrong atypical_yn
# Clip_00033: frame 32: object 1: wrong category
# Clip_00033: frame 32: object 1: wrong atypical_yn
# Clip_00033: frame 33: object 1: wrong category
# Clip_00033: frame 33: object 1: wrong atypical_yn
# Clip_00033: frame 34: object 1: wrong category
# Clip_00033: frame 34: object 1: wrong atypical_yn
# Clip_00033: frame 35: object 1: wrong category
# Clip_00033: frame 35: object 1: wrong atypical_yn
# Clip_00033: frame 36: object 1: wrong category
# Clip_00033: frame 36: object 1: wrong atypical_yn
# Clip_00033: frame 37: object 1: wrong category
# Clip_00033: frame 37: object 1: wrong atypical_yn
# Clip_00033: frame 38: object 1: wrong category
# Clip_00033: frame 38: object 1: wrong atypical_yn
# Clip_00033: frame 39: object 1: wrong category
# Clip_00033: frame 39: object 1: wrong atypical_yn
# Clip_00033: frame 40: object 1: wrong category
# Clip_00033: frame 40: object 1: wrong atypical_yn
# Clip_00033: frame 41: object 1: wrong category
# Clip_00033: frame 41: object 1: wrong atypical_yn
# Clip_00033: frame 42: object 1: wrong category
# Clip_00033: frame 42: object 1: wrong atypical_yn
# Clip_00033: frame 43: object 1: wrong category
# Clip_00033: frame 43: object 1: wrong atypical_yn
# Clip_00033: frame 44: object 1: wrong category
# Clip_00033: frame 44: object 1: wrong atypical_yn
# Clip_00033: frame 45: object 1: wrong category
# Clip_00033: frame 45: object 1: wrong atypical_yn
# Clip_00033: frame 46: object 1: wrong category
# Clip_00033: frame 46: object 1: wrong atypical_yn
# Clip_00033: frame 47: object 1: wrong category
# Clip_00033: frame 47: object 1: wrong atypical_yn
# Clip_00033: frame 48: object 1: wrong category
# Clip_00033: frame 48: object 1: wrong atypical_yn
# Clip_00033: frame 49: object 1: wrong category
# Clip_00033: frame 49: object 1: wrong atypical_yn
# Clip_00033: frame 50: object 1: wrong category
# Clip_00033: frame 50: object 1: wrong atypical_yn
# Clip_00033: frame 51: object 1: wrong category
# Clip_00033: frame 51: object 1: wrong atypical_yn
# Clip_00033: frame 52: object 1: wrong category
# Clip_00033: frame 52: object 1: wrong atypical_yn
# Clip_00033: frame 52: object 5: wrong atypical_yn
# Clip_00033: frame 53: object 1: wrong category
# Clip_00033: frame 53: object 1: wrong atypical_yn
# Clip_00033: frame 53: object 5: wrong atypical_yn
# Clip_00033: frame 54: object 1: wrong category
# Clip_00033: frame 54: object 1: wrong atypical_yn
# Clip_00033: frame 54: object 5: wrong atypical_yn
# Clip_00033: frame 55: object 1: wrong category
# Clip_00033: frame 55: object 1: wrong atypical_yn
# Clip_00033: frame 55: object 5: wrong atypical_yn
# Clip_00033: frame 56: object 1: wrong category
# Clip_00033: frame 56: object 1: wrong atypical_yn
# Clip_00033: frame 56: object 5: wrong atypical_yn
# Clip_00033: frame 57: object 1: wrong category
# Clip_00033: frame 57: object 1: wrong atypical_yn
# Clip_00033: frame 57: object 5: wrong atypical_yn
# Clip_00033: frame 58: object 1: wrong category
# Clip_00033: frame 58: object 1: wrong atypical_yn
# Clip_00033: frame 58: object 5: wrong atypical_yn
# Clip_00033: frame 59: object 1: wrong category
# Clip_00033: frame 59: object 1: wrong atypical_yn
# Clip_00033: frame 59: object 5: wrong atypical_yn
# Clip_00033: frame 60: object 1: wrong category
# Clip_00033: frame 60: object 1: wrong atypical_yn
# Clip_00033: frame 60: object 5: wrong atypical_yn
# Clip_00033: frame 61: object 1: wrong category
# Clip_00033: frame 61: object 1: wrong atypical_yn
# Clip_00033: frame 61: object 5: wrong atypical_yn
# Clip_00033: frame 62: object 1: wrong category
# Clip_00033: frame 62: object 1: wrong atypical_yn
# Clip_00033: frame 62: object 5: wrong atypical_yn
# Clip_00033: frame 63: object 1: wrong category
# Clip_00033: frame 63: object 1: wrong atypical_yn
# Clip_00033: frame 63: object 5: wrong atypical_yn
# Clip_00033: frame 64: object 1: wrong category
# Clip_00033: frame 64: object 1: wrong atypical_yn
# Clip_00033: frame 64: object 5: wrong atypical_yn
# Clip_00033: frame 65: object 1: wrong category
# Clip_00033: frame 65: object 1: wrong atypical_yn
# Clip_00033: frame 65: object 5: wrong atypical_yn
# Clip_00033: frame 66: object 1: wrong category
# Clip_00033: frame 66: object 1: wrong atypical_yn
# Clip_00033: frame 66: object 5: wrong atypical_yn
# Clip_00033: frame 67: object 1: wrong category
# Clip_00033: frame 67: object 1: wrong atypical_yn
# Clip_00033: frame 67: object 5: wrong atypical_yn
# Clip_00033: frame 68: object 1: wrong category
# Clip_00033: frame 68: object 1: wrong atypical_yn
# Clip_00033: frame 68: object 5: wrong atypical_yn
# Clip_00033: frame 69: object 1: wrong category
# Clip_00033: frame 69: object 1: wrong atypical_yn
# Clip_00033: frame 69: object 5: wrong atypical_yn
# Clip_00033: frame 70: object 1: wrong category
# Clip_00033: frame 70: object 1: wrong atypical_yn
# Clip_00033: frame 70: object 5: wrong atypical_yn
# Clip_00033: frame 71: object 1: wrong category
# Clip_00033: frame 71: object 1: wrong atypical_yn
# Clip_00033: frame 71: object 5: wrong atypical_yn
# Clip_00033: frame 72: object 1: wrong category
# Clip_00033: frame 72: object 1: wrong atypical_yn
# Clip_00033: frame 72: object 5: wrong atypical_yn
# Clip_00033: frame 73: object 1: wrong category
# Clip_00033: frame 73: object 1: wrong atypical_yn
# Clip_00033: frame 73: object 5: wrong atypical_yn
# Clip_00033: frame 74: object 1: wrong category
# Clip_00033: frame 74: object 1: wrong atypical_yn
# Clip_00033: frame 74: object 5: wrong atypical_yn
# Clip_00033: frame 75: object 1: wrong category
# Clip_00033: frame 75: object 1: wrong atypical_yn
# Clip_00033: frame 75: object 5: wrong atypical_yn
# Clip_00033: frame 76: object 1: wrong category
# Clip_00033: frame 76: object 1: wrong atypical_yn
# Clip_00033: frame 76: object 5: wrong atypical_yn
# Clip_00033: frame 77: object 1: wrong category
# Clip_00033: frame 77: object 1: wrong atypical_yn
# Clip_00033: frame 77: object 5: wrong atypical_yn
# Clip_00033: frame 78: object 1: wrong category
# Clip_00033: frame 78: object 1: wrong atypical_yn
# Clip_00033: frame 79: object 1: wrong category
# Clip_00033: frame 79: object 1: wrong atypical_yn
# Clip_00033: frame 80: object 1: wrong category
# Clip_00033: frame 80: object 1: wrong atypical_yn
# Clip_00033: frame 81: object 1: wrong category
# Clip_00033: frame 81: object 1: wrong atypical_yn
# Clip_00033: frame 82: object 1: wrong category
# Clip_00033: frame 82: object 1: wrong atypical_yn
# Clip_00033: frame 83: object 1: wrong category
# Clip_00033: frame 83: object 1: wrong atypical_yn
# Clip_00033: frame 84: object 1: wrong category
# Clip_00033: frame 84: object 1: wrong atypical_yn
# Clip_00033: frame 85: object 1: wrong category
# Clip_00033: frame 85: object 1: wrong atypical_yn
# Clip_00033: frame 86: object 1: wrong category
# Clip_00033: frame 86: object 1: wrong atypical_yn
# Clip_00033: frame 87: object 1: wrong category
# Clip_00033: frame 87: object 1: wrong atypical_yn
# Clip_00033: frame 88: object 1: wrong category
# Clip_00033: frame 88: object 1: wrong atypical_yn
# Clip_00033: frame 89: object 1: wrong category
# Clip_00033: frame 89: object 1: wrong atypical_yn
# Clip_00033: frame 90: object 1: wrong category
# Clip_00033: frame 90: object 1: wrong atypical_yn
# Clip_00033: frame 91: object 1: wrong category
# Clip_00033: frame 91: object 1: wrong atypical_yn
# Clip_00033: frame 92: object 1: wrong category
# Clip_00033: frame 92: object 1: wrong atypical_yn
# Clip_00033: frame 92: object 9: wrong atypical_yn
# Clip_00033: frame 93: object 1: wrong category
# Clip_00033: frame 93: object 1: wrong atypical_yn
# Clip_00033: frame 93: object 9: wrong atypical_yn
# Clip_00033: frame 94: object 1: wrong category
# Clip_00033: frame 94: object 1: wrong atypical_yn
# Clip_00033: frame 94: object 9: wrong atypical_yn
# Clip_00033: frame 95: object 1: wrong category
# Clip_00033: frame 95: object 1: wrong atypical_yn
# Clip_00033: frame 95: object 9: wrong atypical_yn
# Clip_00033: frame 96: object 1: wrong category
# Clip_00033: frame 96: object 1: wrong atypical_yn
# Clip_00033: frame 96: object 9: wrong atypical_yn
# Clip_00033: frame 97: object 1: wrong category
# Clip_00033: frame 97: object 1: wrong atypical_yn
# Clip_00033: frame 97: object 9: wrong atypical_yn
# Clip_00033: frame 98: object 1: wrong category
# Clip_00033: frame 98: object 1: wrong atypical_yn
# Clip_00033: frame 98: object 9: wrong atypical_yn
# Clip_00033: frame 99: object 1: wrong category
# Clip_00033: frame 99: object 1: wrong atypical_yn
# Clip_00033: frame 99: object 9: wrong atypical_yn
# Clip_00033: frame 100: object 1: wrong category
# Clip_00033: frame 100: object 1: wrong atypical_yn
# Clip_00033: frame 100: object 9: wrong atypical_yn
# Clip_00035: frame 1: object 1: wrong atypical_yn
# Clip_00035: frame 1: object 2: wrong atypical_yn
# Clip_00035: frame 1: object 3: wrong atypical_yn
# Clip_00035: frame 2: object 1: wrong atypical_yn
# Clip_00035: frame 2: object 2: wrong atypical_yn
# Clip_00035: frame 2: object 3: wrong atypical_yn
# Clip_00035: frame 3: object 1: wrong atypical_yn
# Clip_00035: frame 3: object 2: wrong atypical_yn
# Clip_00035: frame 3: object 3: wrong atypical_yn
# Clip_00035: frame 4: object 1: wrong atypical_yn
# Clip_00035: frame 4: object 2: wrong atypical_yn
# Clip_00035: frame 4: object 3: wrong atypical_yn
# Clip_00035: frame 5: object 1: wrong atypical_yn
# Clip_00035: frame 5: object 2: wrong atypical_yn
# Clip_00035: frame 5: object 3: wrong atypical_yn
# Clip_00035: frame 6: object 1: wrong atypical_yn
# Clip_00035: frame 6: object 2: wrong atypical_yn
# Clip_00035: frame 6: object 3: wrong atypical_yn
# Clip_00035: frame 7: object 1: wrong atypical_yn
# Clip_00035: frame 7: object 2: wrong atypical_yn
# Clip_00035: frame 7: object 3: wrong atypical_yn
# Clip_00035: frame 8: object 1: wrong atypical_yn
# Clip_00035: frame 8: object 2: wrong atypical_yn
# Clip_00035: frame 8: object 3: wrong atypical_yn
# Clip_00035: frame 9: object 1: wrong atypical_yn
# Clip_00035: frame 9: object 2: wrong atypical_yn
# Clip_00035: frame 9: object 3: wrong atypical_yn
# Clip_00035: frame 10: object 1: wrong atypical_yn
# Clip_00035: frame 10: object 2: wrong atypical_yn
# Clip_00035: frame 10: object 3: wrong atypical_yn
# Clip_00035: frame 11: object 1: wrong atypical_yn
# Clip_00035: frame 11: object 2: wrong atypical_yn
# Clip_00035: frame 11: object 3: wrong atypical_yn
# Clip_00035: frame 12: object 1: wrong atypical_yn
# Clip_00035: frame 12: object 2: wrong atypical_yn
# Clip_00035: frame 12: object 3: wrong atypical_yn
# Clip_00035: frame 13: object 1: wrong atypical_yn
# Clip_00035: frame 13: object 2: wrong atypical_yn
# Clip_00035: frame 13: object 3: wrong atypical_yn
# Clip_00035: frame 14: object 1: wrong atypical_yn
# Clip_00035: frame 14: object 2: wrong atypical_yn
# Clip_00035: frame 14: object 3: wrong atypical_yn
# Clip_00035: frame 15: object 1: wrong atypical_yn
# Clip_00035: frame 15: object 2: wrong atypical_yn
# Clip_00035: frame 15: object 3: wrong atypical_yn
# Clip_00035: frame 16: object 2: wrong atypical_yn
# Clip_00035: frame 16: object 3: wrong atypical_yn
# Clip_00035: frame 17: object 2: wrong atypical_yn
# Clip_00035: frame 17: object 3: wrong atypical_yn
# Clip_00035: frame 18: object 2: wrong atypical_yn
# Clip_00035: frame 18: object 3: wrong atypical_yn
# Clip_00035: frame 19: object 2: wrong atypical_yn
# Clip_00035: frame 19: object 3: wrong atypical_yn
# Clip_00035: frame 20: object 2: wrong atypical_yn
# Clip_00035: frame 20: object 3: wrong atypical_yn
# Clip_00035: frame 21: object 2: wrong atypical_yn
# Clip_00035: frame 21: object 3: wrong atypical_yn
# Clip_00035: frame 22: object 2: wrong atypical_yn
# Clip_00035: frame 22: object 3: wrong atypical_yn
# Clip_00035: frame 23: object 2: wrong atypical_yn
# Clip_00035: frame 23: object 3: wrong atypical_yn
# Clip_00035: frame 24: object 2: wrong atypical_yn
# Clip_00035: frame 24: object 3: wrong atypical_yn
# Clip_00035: frame 25: object 2: wrong atypical_yn
# Clip_00035: frame 25: object 3: wrong atypical_yn
# Clip_00035: frame 26: object 2: wrong atypical_yn
# Clip_00035: frame 26: object 3: wrong atypical_yn
# Clip_00035: frame 27: object 2: wrong atypical_yn
# Clip_00035: frame 27: object 3: wrong atypical_yn
# Clip_00035: frame 28: object 2: wrong atypical_yn
# Clip_00035: frame 28: object 3: wrong atypical_yn
# Clip_00035: frame 29: object 2: wrong atypical_yn
# Clip_00035: frame 29: object 3: wrong atypical_yn
# Clip_00035: frame 30: object 2: wrong atypical_yn
# Clip_00035: frame 30: object 3: wrong atypical_yn
# Clip_00035: frame 31: object 2: wrong atypical_yn
# Clip_00035: frame 31: object 3: wrong atypical_yn
# Clip_00035: frame 32: object 2: wrong atypical_yn
# Clip_00035: frame 32: object 3: wrong atypical_yn
# Clip_00035: frame 33: object 2: wrong atypical_yn
# Clip_00035: frame 33: object 3: wrong atypical_yn
# Clip_00035: frame 34: object 2: wrong atypical_yn
# Clip_00035: frame 34: object 3: wrong atypical_yn
# Clip_00035: frame 35: object 2: wrong atypical_yn
# Clip_00035: frame 35: object 3: wrong atypical_yn
# Clip_00035: frame 36: object 2: wrong atypical_yn
# Clip_00035: frame 36: object 3: wrong atypical_yn
# Clip_00035: frame 37: object 2: wrong atypical_yn
# Clip_00035: frame 37: object 3: wrong atypical_yn
# Clip_00035: frame 38: object 2: wrong atypical_yn
# Clip_00035: frame 38: object 3: wrong atypical_yn
# Clip_00035: frame 39: object 2: wrong atypical_yn
# Clip_00035: frame 39: object 3: wrong atypical_yn
# Clip_00035: frame 40: object 2: wrong atypical_yn
# Clip_00035: frame 40: object 3: wrong atypical_yn
# Clip_00035: frame 41: object 2: wrong atypical_yn
# Clip_00035: frame 41: object 3: wrong atypical_yn
# Clip_00035: frame 42: object 2: wrong atypical_yn
# Clip_00035: frame 42: object 3: wrong atypical_yn
# Clip_00035: frame 43: object 2: wrong atypical_yn
# Clip_00035: frame 43: object 3: wrong atypical_yn
# Clip_00035: frame 44: object 2: wrong atypical_yn
# Clip_00035: frame 44: object 3: wrong atypical_yn
# Clip_00035: frame 45: object 2: wrong atypical_yn
# Clip_00035: frame 45: object 3: wrong atypical_yn
# Clip_00035: frame 46: object 2: wrong atypical_yn
# Clip_00035: frame 46: object 3: wrong atypical_yn
# Clip_00035: frame 47: object 2: wrong atypical_yn
# Clip_00035: frame 47: object 3: wrong atypical_yn
# Clip_00035: frame 48: object 2: wrong atypical_yn
# Clip_00035: frame 48: object 3: wrong atypical_yn
# Clip_00035: frame 49: object 2: wrong atypical_yn
# Clip_00035: frame 49: object 3: wrong atypical_yn
# Clip_00035: frame 50: object 2: wrong atypical_yn
# Clip_00035: frame 50: object 3: wrong atypical_yn
# Clip_00035: frame 51: object 2: wrong atypical_yn
# Clip_00035: frame 51: object 3: wrong atypical_yn
# Clip_00035: frame 52: object 2: wrong atypical_yn
# Clip_00035: frame 52: object 3: wrong atypical_yn
# Clip_00035: frame 53: object 2: wrong atypical_yn
# Clip_00035: frame 53: object 3: wrong atypical_yn
# Clip_00035: frame 54: object 2: wrong atypical_yn
# Clip_00035: frame 54: object 3: wrong atypical_yn
# Clip_00035: frame 55: object 2: wrong atypical_yn
# Clip_00035: frame 55: object 3: wrong atypical_yn
# Clip_00035: frame 56: object 2: wrong atypical_yn
# Clip_00035: frame 56: object 3: wrong atypical_yn
# Clip_00035: frame 57: object 2: wrong atypical_yn
# Clip_00035: frame 57: object 3: wrong atypical_yn
# Clip_00035: frame 58: object 2: wrong atypical_yn
# Clip_00035: frame 58: object 3: wrong atypical_yn
# Clip_00035: frame 59: object 2: wrong atypical_yn
# Clip_00035: frame 59: object 3: wrong atypical_yn
# Clip_00035: frame 60: object 2: wrong atypical_yn
# Clip_00035: frame 60: object 3: wrong atypical_yn
# Clip_00035: frame 61: object 2: wrong atypical_yn
# Clip_00035: frame 61: object 3: wrong atypical_yn
# Clip_00035: frame 62: object 2: wrong atypical_yn
# Clip_00035: frame 62: object 3: wrong atypical_yn
# Clip_00035: frame 63: object 2: wrong atypical_yn
# Clip_00035: frame 63: object 3: wrong atypical_yn
# Clip_00035: frame 64: object 2: wrong atypical_yn
# Clip_00035: frame 64: object 3: wrong atypical_yn
# Clip_00035: frame 65: object 2: wrong atypical_yn
# Clip_00035: frame 65: object 3: wrong atypical_yn
# Clip_00035: frame 66: object 2: wrong atypical_yn
# Clip_00035: frame 66: object 3: wrong atypical_yn
# Clip_00035: frame 67: object 2: wrong atypical_yn
# Clip_00035: frame 67: object 3: wrong atypical_yn
# Clip_00035: frame 68: object 2: wrong atypical_yn
# Clip_00035: frame 68: object 3: wrong atypical_yn
# Clip_00035: frame 69: object 2: wrong atypical_yn
# Clip_00035: frame 69: object 3: wrong atypical_yn
# Clip_00035: frame 70: object 2: wrong atypical_yn
# Clip_00035: frame 70: object 3: wrong atypical_yn
# Clip_00035: frame 71: object 2: wrong atypical_yn
# Clip_00035: frame 71: object 3: wrong atypical_yn
# Clip_00035: frame 72: object 2: wrong atypical_yn
# Clip_00035: frame 72: object 3: wrong atypical_yn
# Clip_00035: frame 73: object 2: wrong atypical_yn
# Clip_00035: frame 73: object 3: wrong atypical_yn
# Clip_00035: frame 74: object 2: wrong atypical_yn
# Clip_00035: frame 74: object 3: wrong atypical_yn
# Clip_00035: frame 75: object 2: wrong atypical_yn
# Clip_00035: frame 75: object 3: wrong atypical_yn
# Clip_00035: frame 76: object 2: wrong atypical_yn
# ...
# Clip_00056: frame 26: object 3: wrong atypical_yn
# Clip_00056: frame 26: object 5: wrong atypical_yn
# Clip_00056: frame 27: object 1: wrong atypical_yn
# Clip_00056: frame 27: object 2: wrong atypical_yn
# Clip_00056: frame 27: object 3: wrong atypical_yn
# Clip_00056: frame 27: object 5: wrong atypical_yn
# Clip_00056: frame 28: object 1: wrong atypical_yn
# Clip_00056: frame 28: object 2: wrong atypical_yn
# Clip_00056: frame 28: object 3: wrong atypical_yn
# Clip_00056: frame 28: object 5: wrong atypical_yn
# Clip_00056: frame 29: object 1: wrong atypical_yn
# Clip_00056: frame 29: object 2: wrong atypical_yn
# Clip_00056: frame 29: object 3: wrong atypical_yn
# Clip_00056: frame 29: object 5: wrong atypical_yn
# Clip_00056: frame 30: object 1: wrong atypical_yn
# Clip_00056: frame 30: object 2: wrong atypical_yn
# Clip_00056: frame 30: object 3: wrong atypical_yn
# Clip_00056: frame 30: object 5: wrong atypical_yn
# Clip_00056: frame 31: object 1: wrong atypical_yn
# Clip_00056: frame 31: object 2: wrong atypical_yn
# Clip_00056: frame 31: object 3: wrong atypical_yn
# Clip_00056: frame 31: object 5: wrong atypical_yn
# Clip_00056: frame 32: object 1: wrong atypical_yn
# Clip_00056: frame 32: object 2: wrong atypical_yn
# Clip_00056: frame 32: object 3: wrong atypical_yn
# Clip_00056: frame 32: object 5: wrong atypical_yn
# Clip_00056: frame 33: object 1: wrong atypical_yn
# Clip_00056: frame 33: object 2: wrong atypical_yn
# Clip_00056: frame 33: object 3: wrong atypical_yn
# Clip_00056: frame 33: object 5: wrong atypical_yn
# Clip_00056: frame 34: object 1: wrong atypical_yn
# Clip_00056: frame 34: object 2: wrong atypical_yn
# Clip_00056: frame 34: object 3: wrong atypical_yn
# Clip_00056: frame 34: object 5: wrong atypical_yn
# Clip_00056: frame 35: object 2: wrong atypical_yn
# Clip_00056: frame 35: object 3: wrong atypical_yn
# Clip_00056: frame 35: object 5: wrong atypical_yn
# Clip_00056: frame 36: object 2: wrong atypical_yn
# Clip_00056: frame 36: object 3: wrong atypical_yn
# Clip_00056: frame 36: object 5: wrong atypical_yn
# Clip_00056: frame 37: object 2: wrong atypical_yn
# Clip_00056: frame 37: object 3: wrong atypical_yn
# Clip_00056: frame 37: object 5: wrong atypical_yn
# Clip_00056: frame 38: object 2: wrong atypical_yn
# Clip_00056: frame 38: object 3: wrong atypical_yn
# Clip_00056: frame 38: object 5: wrong atypical_yn
# Clip_00056: frame 39: object 2: wrong atypical_yn
# Clip_00056: frame 39: object 3: wrong atypical_yn
# Clip_00056: frame 39: object 5: wrong atypical_yn
# Clip_00056: frame 40: object 2: wrong atypical_yn
# Clip_00056: frame 40: object 3: wrong atypical_yn
# Clip_00056: frame 40: object 5: wrong atypical_yn
# Clip_00056: frame 41: object 2: wrong atypical_yn
# Clip_00056: frame 41: object 3: wrong atypical_yn
# Clip_00056: frame 41: object 5: wrong atypical_yn
# Clip_00056: frame 42: object 2: wrong atypical_yn
# Clip_00056: frame 42: object 3: wrong atypical_yn
# Clip_00056: frame 42: object 5: wrong atypical_yn
# Clip_00056: frame 43: object 2: wrong atypical_yn
# Clip_00056: frame 43: object 3: wrong atypical_yn
# Clip_00056: frame 43: object 5: wrong atypical_yn
# Clip_00056: frame 44: object 2: wrong atypical_yn
# Clip_00056: frame 44: object 3: wrong atypical_yn
# Clip_00056: frame 44: object 5: wrong atypical_yn
# Clip_00056: frame 45: object 2: wrong atypical_yn
# Clip_00056: frame 45: object 3: wrong atypical_yn
# Clip_00056: frame 45: object 5: wrong atypical_yn
# Clip_00056: frame 46: object 2: wrong atypical_yn
# Clip_00056: frame 46: object 3: wrong atypical_yn
# Clip_00056: frame 46: object 5: wrong atypical_yn
# Clip_00056: frame 47: object 2: wrong atypical_yn
# Clip_00056: frame 47: object 3: wrong atypical_yn
# Clip_00056: frame 47: object 5: wrong atypical_yn
# Clip_00056: frame 48: object 2: wrong atypical_yn
# Clip_00056: frame 48: object 3: wrong atypical_yn
# Clip_00056: frame 48: object 5: wrong atypical_yn
# Clip_00056: frame 49: object 2: wrong atypical_yn
# Clip_00056: frame 49: object 3: wrong atypical_yn
# Clip_00056: frame 49: object 5: wrong atypical_yn
# Clip_00056: frame 50: object 2: wrong atypical_yn
# Clip_00056: frame 50: object 3: wrong atypical_yn
# Clip_00056: frame 50: object 5: wrong atypical_yn
# Clip_00056: frame 51: object 2: wrong atypical_yn
# Clip_00056: frame 51: object 3: wrong atypical_yn
# Clip_00056: frame 51: object 5: wrong atypical_yn
# Clip_00056: frame 52: object 2: wrong atypical_yn
# Clip_00056: frame 52: object 3: wrong atypical_yn
# Clip_00056: frame 52: object 5: wrong atypical_yn
# Clip_00056: frame 53: object 2: wrong atypical_yn
# Clip_00056: frame 53: object 3: wrong atypical_yn
# Clip_00056: frame 53: object 5: wrong atypical_yn
# Clip_00056: frame 54: object 2: wrong atypical_yn
# Clip_00056: frame 54: object 3: wrong atypical_yn
# Clip_00056: frame 54: object 5: wrong atypical_yn
# Clip_00056: frame 55: object 2: wrong atypical_yn
# Clip_00056: frame 55: object 3: wrong atypical_yn
# Clip_00056: frame 55: object 5: wrong atypical_yn
# Clip_00056: frame 56: object 2: wrong atypical_yn
# Clip_00056: frame 56: object 3: wrong atypical_yn
# Clip_00056: frame 56: object 5: wrong atypical_yn
# Clip_00056: frame 57: object 2: wrong atypical_yn
# Clip_00056: frame 57: object 3: wrong atypical_yn
# Clip_00056: frame 57: object 5: wrong atypical_yn
# Clip_00056: frame 58: object 2: wrong atypical_yn
# Clip_00056: frame 58: object 3: wrong atypical_yn
# Clip_00056: frame 58: object 5: wrong atypical_yn
# Clip_00056: frame 59: object 2: wrong atypical_yn
# Clip_00056: frame 59: object 3: wrong atypical_yn
# Clip_00056: frame 59: object 5: wrong atypical_yn
# Clip_00056: frame 60: object 2: wrong atypical_yn
# Clip_00056: frame 60: object 3: wrong atypical_yn
# Clip_00056: frame 60: object 5: wrong atypical_yn
# Clip_00056: frame 61: object 2: wrong atypical_yn
# Clip_00056: frame 61: object 3: wrong atypical_yn
# Clip_00056: frame 61: object 5: wrong atypical_yn
# Clip_00056: frame 62: object 2: wrong atypical_yn
# Clip_00056: frame 62: object 3: wrong atypical_yn
# Clip_00056: frame 62: object 5: wrong atypical_yn
# Clip_00056: frame 63: object 2: wrong atypical_yn
# Clip_00056: frame 63: object 3: wrong atypical_yn
# Clip_00056: frame 63: object 5: wrong atypical_yn
# Clip_00056: frame 64: object 2: wrong atypical_yn
# Clip_00056: frame 64: object 3: wrong atypical_yn
# Clip_00056: frame 64: object 5: wrong atypical_yn
# Clip_00056: frame 65: object 2: wrong atypical_yn
# Clip_00056: frame 65: object 3: wrong atypical_yn
# Clip_00056: frame 65: object 5: wrong atypical_yn
# Clip_00056: frame 66: object 2: wrong atypical_yn
# Clip_00056: frame 66: object 3: wrong atypical_yn
# Clip_00056: frame 66: object 5: wrong atypical_yn
# Clip_00056: frame 67: object 2: wrong atypical_yn
# Clip_00056: frame 67: object 3: wrong atypical_yn
# Clip_00056: frame 67: object 5: wrong atypical_yn
# Clip_00056: frame 68: object 2: wrong atypical_yn
# Clip_00056: frame 68: object 3: wrong atypical_yn
# Clip_00056: frame 68: object 5: wrong atypical_yn
# Clip_00056: frame 69: object 2: wrong atypical_yn
# Clip_00056: frame 69: object 3: wrong atypical_yn
# Clip_00056: frame 69: object 5: wrong atypical_yn
# Clip_00056: frame 70: object 2: wrong atypical_yn
# Clip_00056: frame 70: object 3: wrong atypical_yn
# Clip_00056: frame 70: object 5: wrong atypical_yn
# Clip_00056: frame 71: object 2: wrong atypical_yn
# Clip_00056: frame 71: object 3: wrong atypical_yn
# Clip_00056: frame 71: object 5: wrong atypical_yn
# Clip_00056: frame 72: object 2: wrong atypical_yn
# Clip_00056: frame 72: object 3: wrong atypical_yn
# Clip_00056: frame 72: object 5: wrong atypical_yn
# Clip_00056: frame 73: object 2: wrong atypical_yn
# Clip_00056: frame 73: object 3: wrong atypical_yn
# Clip_00056: frame 73: object 5: wrong atypical_yn
# Clip_00056: frame 74: object 2: wrong atypical_yn
# Clip_00056: frame 74: object 3: wrong atypical_yn
# Clip_00056: frame 74: object 5: wrong atypical_yn
# Clip_00056: frame 75: object 2: wrong atypical_yn
# Clip_00056: frame 75: object 3: wrong atypical_yn
# Clip_00056: frame 75: object 5: wrong atypical_yn
# Clip_00056: frame 76: object 2: wrong atypical_yn
# Clip_00056: frame 76: object 3: wrong atypical_yn
# Clip_00056: frame 76: object 5: wrong atypical_yn
# Clip_00056: frame 77: object 2: wrong atypical_yn
# Clip_00056: frame 77: object 3: wrong atypical_yn
# Clip_00056: frame 77: object 5: wrong atypical_yn
# Clip_00056: frame 78: object 2: wrong atypical_yn
# Clip_00056: frame 78: object 3: wrong atypical_yn
# Clip_00056: frame 78: object 5: wrong atypical_yn
# Clip_00056: frame 79: object 2: wrong atypical_yn
# Clip_00056: frame 79: object 3: wrong atypical_yn
# Clip_00056: frame 79: object 5: wrong atypical_yn
# Clip_00056: frame 80: object 2: wrong atypical_yn
# Clip_00056: frame 80: object 3: wrong atypical_yn
# Clip_00056: frame 80: object 5: wrong atypical_yn
# Clip_00056: frame 81: object 2: wrong atypical_yn
# Clip_00056: frame 81: object 3: wrong atypical_yn
# Clip_00056: frame 81: object 5: wrong atypical_yn
# Clip_00056: frame 82: object 2: wrong atypical_yn
# Clip_00056: frame 82: object 3: wrong atypical_yn
# Clip_00056: frame 82: object 5: wrong atypical_yn
# Clip_00056: frame 83: object 2: wrong atypical_yn
# Clip_00056: frame 83: object 3: wrong atypical_yn
# Clip_00056: frame 83: object 5: wrong atypical_yn
# Clip_00056: frame 84: object 2: wrong atypical_yn
# Clip_00056: frame 84: object 3: wrong atypical_yn
# Clip_00056: frame 84: object 5: wrong atypical_yn
# Clip_00056: frame 85: object 2: wrong atypical_yn
# Clip_00056: frame 85: object 3: wrong atypical_yn
# Clip_00056: frame 85: object 5: wrong atypical_yn
# Clip_00056: frame 86: object 2: wrong atypical_yn
# Clip_00056: frame 86: object 3: wrong atypical_yn
# Clip_00056: frame 86: object 5: wrong atypical_yn
# Clip_00056: frame 87: object 2: wrong atypical_yn
# Clip_00056: frame 87: object 3: wrong atypical_yn
# Clip_00056: frame 87: object 5: wrong atypical_yn
# Clip_00056: frame 88: object 2: wrong atypical_yn
# Clip_00056: frame 88: object 3: wrong atypical_yn
# Clip_00056: frame 88: object 5: wrong atypical_yn
# Clip_00056: frame 89: object 2: wrong atypical_yn
# Clip_00056: frame 89: object 3: wrong atypical_yn
# Clip_00056: frame 89: object 5: wrong atypical_yn
# Clip_00056: frame 90: object 2: wrong atypical_yn
# Clip_00056: frame 90: object 3: wrong atypical_yn
# Clip_00056: frame 90: object 5: wrong atypical_yn
# Clip_00056: frame 91: object 2: wrong atypical_yn
# Clip_00056: frame 91: object 3: wrong atypical_yn
# Clip_00056: frame 91: object 5: wrong atypical_yn
# Clip_00056: frame 91: object 6: wrong atypical_yn
# Clip_00056: frame 92: object 2: wrong atypical_yn
# Clip_00056: frame 92: object 3: wrong atypical_yn
# Clip_00056: frame 92: object 5: wrong atypical_yn
# Clip_00056: frame 92: object 6: wrong atypical_yn
# Clip_00056: frame 93: object 2: wrong atypical_yn
# Clip_00056: frame 93: object 3: wrong atypical_yn
# Clip_00056: frame 93: object 5: wrong atypical_yn
# Clip_00056: frame 93: object 6: wrong atypical_yn
# Clip_00056: frame 94: object 2: wrong atypical_yn
# Clip_00056: frame 94: object 3: wrong atypical_yn
# Clip_00056: frame 94: object 5: wrong atypical_yn
# Clip_00056: frame 94: object 6: wrong atypical_yn
# Clip_00056: frame 95: object 2: wrong atypical_yn
# Clip_00056: frame 95: object 3: wrong atypical_yn
# Clip_00056: frame 95: object 5: wrong atypical_yn
# Clip_00056: frame 95: object 6: wrong atypical_yn
# Clip_00056: frame 96: object 2: wrong atypical_yn
# Clip_00056: frame 96: object 3: wrong atypical_yn
# Clip_00056: frame 96: object 5: wrong atypical_yn
# Clip_00056: frame 96: object 6: wrong atypical_yn
# Clip_00056: frame 97: object 2: wrong atypical_yn
# Clip_00056: frame 97: object 3: wrong atypical_yn
# Clip_00056: frame 97: object 5: wrong atypical_yn
# Clip_00056: frame 97: object 6: wrong atypical_yn
# Clip_00056: frame 98: object 2: wrong atypical_yn
# Clip_00056: frame 98: object 3: wrong atypical_yn
# Clip_00056: frame 98: object 5: wrong atypical_yn
# Clip_00056: frame 98: object 6: wrong atypical_yn
# Clip_00056: frame 99: object 2: wrong atypical_yn
# Clip_00056: frame 99: object 3: wrong atypical_yn
# Clip_00056: frame 99: object 5: wrong atypical_yn
# Clip_00056: frame 99: object 6: wrong atypical_yn
# Clip_00056: frame 100: object 2: wrong atypical_yn
# Clip_00056: frame 100: object 3: wrong atypical_yn
# Clip_00056: frame 100: object 5: wrong atypical_yn
# Clip_00056: frame 100: object 6: wrong atypical_yn
# Clip_00060: frame 1: object 12: wrong atypical_yn
# Clip_00060: frame 2: object 13: wrong atypical_yn
# Clip_00060: frame 3: object 13: wrong atypical_yn
# Clip_00060: frame 4: object 13: wrong atypical_yn
# Clip_00060: frame 5: object 13: wrong atypical_yn
# Clip_00060: frame 6: object 13: wrong atypical_yn
# Clip_00061: frame 100: object 11: wrong atypical_yn
# Clip_00076: frame 1: object 1: wrong atypical_yn
# Clip_00076: frame 1: object 2: wrong atypical_yn
# Clip_00076: frame 2: object 1: wrong atypical_yn
# Clip_00076: frame 2: object 2: wrong atypical_yn
# Clip_00076: frame 3: object 1: wrong atypical_yn
# Clip_00076: frame 3: object 3: wrong atypical_yn
# Clip_00076: frame 4: object 1: wrong atypical_yn
# Clip_00076: frame 4: object 4: wrong atypical_yn
# Clip_00076: frame 5: object 1: wrong atypical_yn
# Clip_00076: frame 5: object 5: wrong atypical_yn
# Clip_00076: frame 6: object 1: wrong atypical_yn
# Clip_00076: frame 6: object 6: wrong atypical_yn
# Clip_00076: frame 7: object 7: wrong atypical_yn
# Clip_00076: frame 8: object 7: wrong atypical_yn
# Clip_00076: frame 9: object 7: wrong atypical_yn
# Clip_00076: frame 10: object 7: wrong atypical_yn
# Clip_00076: frame 11: object 7: wrong atypical_yn
# Clip_00076: frame 12: object 7: wrong atypical_yn
# Clip_00076: frame 13: object 7: wrong atypical_yn
# Clip_00076: frame 14: object 7: wrong atypical_yn
# Clip_00076: frame 15: object 7: wrong atypical_yn
# Clip_00076: frame 16: object 7: wrong atypical_yn
# Clip_00076: frame 17: object 7: wrong atypical_yn
# Clip_00076: frame 18: object 7: wrong atypical_yn
# Clip_00076: frame 19: object 7: wrong atypical_yn
# Clip_00076: frame 20: object 7: wrong atypical_yn
# Clip_00076: frame 21: object 7: wrong atypical_yn
# Clip_00076: frame 41: object 3: wrong atypical_yn
# Clip_00076: frame 42: object 3: wrong atypical_yn
# Clip_00076: frame 43: object 3: wrong atypical_yn
# Clip_00076: frame 44: object 3: wrong atypical_yn
# Clip_00076: frame 45: object 3: wrong atypical_yn
# Clip_00076: frame 46: object 3: wrong atypical_yn
# Clip_00076: frame 47: object 3: wrong atypical_yn
# Clip_00076: frame 48: object 3: wrong atypical_yn
# Clip_00076: frame 49: object 3: wrong atypical_yn
# Clip_00076: frame 50: object 3: wrong atypical_yn
# Clip_00076: frame 51: object 3: wrong atypical_yn
# Clip_00076: frame 52: object 3: wrong atypical_yn
# Clip_00076: frame 53: object 3: wrong atypical_yn
# Clip_00076: frame 54: object 3: wrong atypical_yn
# Clip_00076: frame 55: object 3: wrong atypical_yn
# Clip_00076: frame 56: object 3: wrong atypical_yn
# Clip_00076: frame 57: object 3: wrong atypical_yn
# Clip_00076: frame 58: object 3: wrong atypical_yn
# Clip_00076: frame 59: object 3: wrong atypical_yn
# Clip_00076: frame 60: object 3: wrong atypical_yn
# Clip_00076: frame 61: object 3: wrong atypical_yn
# Clip_00076: frame 62: object 3: wrong atypical_yn
# Clip_00076: frame 63: object 3: wrong atypical_yn
# Clip_00076: frame 64: object 3: wrong atypical_yn
# Clip_00076: frame 65: object 3: wrong atypical_yn
# Clip_00076: frame 66: object 3: wrong atypical_yn
# Clip_00076: frame 67: object 3: wrong atypical_yn
# Clip_00076: frame 68: object 3: wrong atypical_yn
# Clip_00076: frame 69: object 3: wrong atypical_yn
# Clip_00076: frame 70: object 3: wrong atypical_yn
# Clip_00076: frame 71: object 3: wrong atypical_yn
# Clip_00076: frame 72: object 3: wrong atypical_yn
# Clip_00076: frame 73: object 3: wrong atypical_yn
# Clip_00076: frame 74: object 3: wrong atypical_yn
# Clip_00076: frame 75: object 3: wrong atypical_yn
# Clip_00076: frame 76: object 3: wrong atypical_yn
# Clip_00076: frame 77: object 3: wrong atypical_yn
# Clip_00076: frame 78: object 3: wrong atypical_yn
# Clip_00076: frame 79: object 3: wrong atypical_yn
# Clip_00076: frame 80: object 3: wrong atypical_yn
# Clip_00076: frame 81: object 3: wrong atypical_yn
# Clip_00076: frame 82: object 3: wrong atypical_yn
# Clip_00076: frame 83: object 3: wrong atypical_yn
# Clip_00076: frame 84: object 3: wrong atypical_yn

# %%
# res.to_csv("./rejecter.csv")

# %%
# base_path = r'C:\workspace\rejecter\가공완료 클립\extract_2022-08-01-10-53-48'

# clip_folders = [i for i in os.listdir(base_path) 
#                 if len(i) == 10 and 'Clip_' in i]

# rejected_clip = []
# for clip in clip_folders:
#     ret, logging = rej_res(base_path, clip)
#     if ret != PASS:
#         rejected_clip.append(ret)
#         err_logging = set(logging)
#         for err in err_logging:
#             print(dic.get(err))
#         print("================")

# print("=========")
# print(rejected_clip)
